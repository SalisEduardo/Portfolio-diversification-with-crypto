# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
import investpy as inv

# %%
inv.indices.get_index_countries()
# Out:
# ['argentina',
#  'australia',
#  'austria',
#  'bahrain',
#  'bangladesh',
#  'belgium',
#  'bosnia',
#  'botswana',
#  'brazil',
#  'bulgaria',
#  'canada',
#  'chile',
#  'china',
#  'colombia',
#  'costa rica',
#  'ivory coast',
#  'croatia',
#  'cyprus',
#  'czech republic',
#  'denmark',
#  'ecuador',
#  'egypt',
#  'estonia',
#  'finland',
#  'france',
#  'germany',
#  'greece',
#  'hong kong',
#  'hungary',
#  'iceland',
#  'india',
#  'indonesia',
#  'iraq',
#  'ireland',
#  'israel',
#  'italy',
#  'jamaica',
#  'japan',
#  'jordan',
#  'kazakhstan',
#  'kenya',
#  'kuwait',
#  'latvia',
#  'lebanon',
#  'lithuania',
#  'luxembourg',
#  'malawi',
#  'malaysia',
#  'malta',
#  'mauritius',
#  'mexico',
#  'mongolia',
#  'montenegro',
#  'morocco',
#  'namibia',
#  'netherlands',
#  'new zealand',
#  'nigeria',
#  'norway',
#  'oman',
#  'pakistan',
#  'palestinian territory',
#  'peru',
#  'philippines',
#  'poland',
#  'portugal',
#  'qatar',
#  'romania',
#  'russia',
#  'rwanda',
#  'saudi arabia',
#  'serbia',
#  'singapore',
#  'slovakia',
#  'slovenia',
#  'south africa',
#  'south korea',
#  'spain',
#  'sri lanka',
#  'sweden',
#  'switzerland',
#  'taiwan',
#  'tanzania',
#  'thailand',
#  'tunisia',
#  'turkey',
#  'uganda',
#  'ukraine',
#  'dubai',
#  'united kingdom',
#  'united states',
#  'venezuela',
#  'vietnam',
#  'world',
#  'zambia',
#  'zimbabwe',
#  'euro zone']

# %%
index_brazil = inv.indices.get_indices(country='brazil')

# %%
index_brazil
# Out:
#    country                                               name  \
# 0   brazil                                MSCI Brazil Net USD
# 1   brazil                                          DJ Brazil
# 2   brazil                                       TR Brazil 50
# 3   brazil                              MSCI Brazil Price USD
# 4   brazil                            DJ Brazil Titans 20 ADR
# 5   brazil                              BNY Mellon Brazil ADR
# 6   brazil                           BNY Mellon Brazil ADR TR
# 7   brazil                      BNY Mellon Brazil Classic ADR
# 8   brazil                   BNY Mellon Brazil Classic ADR TR
# 9   brazil                                FTSE RAFI Brazil 50
# 10  brazil                                  MSCI Brazil 10 40
# 11  brazil                       DJ BRIC Brazil 15 Capped NTR
# 12  brazil                              DJ BRIC Brazil 15 USD
# 13  brazil                              DJ BRIC Brazil 15 EUR
# 14  brazil                FTSE Brazil Infrastructure Extended
# 15  brazil                                  MSCI Brazil Gross
# 16  brazil                         DJ Brazil Titans 20 ADR TR
# 17  brazil                            MSCI Brazil 25-50 Price
# 18  brazil                     MSCI Brazil 20-50 Gross Return
# 19  brazil                       MSCI Brazil 25-50 Net Return
# 20  brazil         FTSE Brazil Infrastructure Extended USD PR
# 21  brazil   FTSE Brazil Infrastructure Extended Total Return
# 22  brazil  FTSE Brazil Infrastructure Extended Net Tax Total
# 23  brazil  FTSE Brazil Infrastructure Extended Net Tax US...
# 24  brazil                               DJ BRIC Brazil 15 DR
# 25  brazil                                        MSCI Brazil
# 26  brazil                       BM&FBOVESPA Unsponsored BDRX
# 27  brazil                                    Small Cap Index
# 28  brazil                                          Tag Along
# 29  brazil                                 Brazil broad-Based
# 30  brazil                                       Brazil Index
# 31  brazil                                Mid-Large Cap Index
# 32  brazil                                   Public Utilities
# 33  brazil                       BM&FBOVESPA Real Estate IFIX
# 34  brazil                                         Financials
# 35  brazil                                   Carbon Efficient
# 36  brazil                         Corporate Governance IGCNM
# 37  brazil                                   Bovespa Dividend
# 38  brazil                                          Brazil 50
# 39  brazil                                Corporate Gov Trade
# 40  brazil                                        FTSE Brazil
# 41  brazil                                       Ibovespa EUR
# 42  brazil                                       Ibovespa USD
# 43  brazil                                               IVBX
# 44  brazil                                               IGCX
# 45  brazil                                        Consumption
# 46  brazil                                  Industrial Sector
# 47  brazil                                  Electrical Energy
# 48  brazil                                    Basic Materials
# 49  brazil                                            Bovespa
# 50  brazil                           Corporate Sustainability
# 51  brazil                                        Real Estate
#
#                                             full_name        symbol currency  \
# 0                                 MSCI Brazil Net USD  MIBR00000NUS      USD
# 1                                    Dow Jones Brazil         BRDOW      BRL
# 2                           Thomson Reuters Brazil 50      TRX50BRP      BRL
# 3                               MSCI Brazil Price USD        MSCIBR      USD
# 4                      Dow Jones Brazil Titans 20 ADR          BR20      USD
# 5                               BNY Mellon Brazil ADR          BKBR      USD
# 6                  BNY Mellon Brazil ADR Total Return         BKBRT      USD
# 7                       BNY Mellon Brazil Classic ADR         BKCBR      USD
# 8          BNY Mellon Brazil Classic ADR Total Return        BKCBRT      USD
# 9                                 FTSE RAFI Brazil 50       FTFRBR5      BRL
# 10                                  MSCI Brazil 10 40  MIBR00005PUS      USD
# 11                       DJ BRIC Brazil 15 Capped NTR      B15BDRCN      USD
# 12                       Dow Jones BRIC Brazil 15 USD        B50BRD      USD
# 13                       Dow Jones BRIC Brazil 15 EUR        B50BRE      EUR
# 14                FTSE Brazil Infrastructure Extended      FTFTBRXX      USD
# 15          MSCI International Brazil Gross Real time  MIBR00000GUS      USD
# 16                         DJ Brazil Titans 20 ADR TR         BR20T      USD
# 17                            MSCI Brazil 25-50 Price  MIBR00002PUS      USD
# 18                     MSCI Brazil 20-50 Gross Return  MIBR00002GUS      USD
# 19                       MSCI Brazil 25-50 Net Return  MIBR00002NUS      USD
# 20         FTSE Brazil Infrastructure Extended USD PR     FTFTBRXXU      USD
# 21   FTSE Brazil Infrastructure Extended Total Return     TRIFTBRXX      USD
# 22  FTSE Brazil Infrastructure Extended Net Tax To...    TRIFTBRXXN      USD
# 23  FTSE Brazil Infrastructure Extended Net Tax US...   TFTFTBRXXNU      USD
# 24                        Dow Jones BRIC Brazil 15 DR       B15BDRD      USD
# 25                                        MSCI Brazil  MIBR00000PUS      USD
# 26                       BM&FBOVESPA Unsponsored BDRX          BDRX      BRL
# 27                                    Small Cap Index          SMLL      BRL
# 28                                  Bovespa Tag Along          ITAG      BRL
# 29                                 Brazil broad-Based          IBRA      BRL
# 30                                       Brazil Index          IBRX      BRL
# 31                                Mid-Large Cap Index          MLCX      BRL
# 32                                   Public Utilities          UTIL      BRL
# 33                       BM&FBOVESPA Real Estate IFIX          IFIX      BRL
# 34                                         Financials          IFNC      BRL
# 35                                   Carbon Efficient          ICO2      BRL
# 36                         Corporate Governance IGCNM         IGCNM      BRL
# 37                                   Bovespa Dividend          DIVI      BRL
# 38                                  Bovespa Brazil 50         IBX50      BRL
# 39                                Corporate Gov Trade          IGCT      BRL
# 40                                        FTSE Brazil      FTWIBRAL      BRL
# 41                                       Ibovespa EUR       BVSPEUR      BRL
# 42                                       Ibovespa USD       BVSPUSD      BRL
# 43                                               IVBX          IVBX      BRL
# 44                                  Sao Paulo SE IGCX          IGCX      BRL
# 45                                        Consumption          ICON      BRL
# 46                          Bovespa Industrial Sector          INDX      BRL
# 47                          Bovespa Electrical Energy           IEE      BRL
# 48                                    Basic Materials          IMAT      BRL
# 49                                            Bovespa          BVSP      BRL
# 50                           Corporate Sustainability           ISE      BRL
# 51                                        Real Estate          IMOB      BRL
#
#                  class          market
# 0        major_indices  global_indices
# 1        major_indices  global_indices
# 2   additional_indices  global_indices
# 3   additional_indices  global_indices
# 4   additional_indices  global_indices
# 5   additional_indices  global_indices
# 6   additional_indices  global_indices
# 7   additional_indices  global_indices
# 8   additional_indices  global_indices
# 9   additional_indices  global_indices
# 10       other_indices  global_indices
# 11       other_indices  global_indices
# 12       other_indices  global_indices
# 13       other_indices  global_indices
# 14       other_indices  global_indices
# 15       other_indices  global_indices
# 16       other_indices  global_indices
# 17       other_indices  global_indices
# 18       other_indices  global_indices
# 19       other_indices  global_indices
# 20       other_indices  global_indices
# 21       other_indices  global_indices
# 22       other_indices  global_indices
# 23       other_indices  global_indices
# 24       other_indices  global_indices
# 25       major_indices  global_indices
# 26       other_indices   world_indices
# 27  additional_indices   world_indices
# 28  additional_indices   world_indices
# 29  additional_indices   world_indices
# 30  additional_indices   world_indices
# 31  additional_indices   world_indices
# 32     primary_sectors   world_indices
# 33       other_indices   world_indices
# 34     primary_sectors   world_indices
# 35       other_indices   world_indices
# 36       other_indices   world_indices
# 37       other_indices   world_indices
# 38  additional_indices   world_indices
# 39       other_indices   world_indices
# 40       other_indices   world_indices
# 41       other_indices   world_indices
# 42       other_indices   world_indices
# 43       other_indices   world_indices
# 44       other_indices   world_indices
# 45     primary_sectors   world_indices
# 46     primary_sectors   world_indices
# 47     primary_sectors   world_indices
# 48     primary_sectors   world_indices
# 49       major_indices   world_indices
# 50       other_indices   world_indices
# 51     primary_sectors   world_indices

# %%
inv.search_cryptos(by = "name"
                   , value = "bitcoin")['currency']
# Out:
# array(['USD', ''], dtype=object)
